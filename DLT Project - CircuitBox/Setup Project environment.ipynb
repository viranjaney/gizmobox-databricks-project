-- %% [markdown]
-- ## Set-up the project environment for CircuitBox Data Lakehouse
-- 1. Create external location - dea_course_ext_dl_circuitbox
-- 1. Create Catalog - circuitbox
-- 1. Create Schemas
--     - landing
--     - lakehouse
-- 1. Create Volume - operational_data

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_circuitbox
  URL 'abfss://circuitbox@deacourseexternaldl100.dfs.core.windows.net/'
  WITH (STORAGE CREDENTIAL dea_course_ext_sc)
  COMMENT 'External Location for the circuitbox data lakehouse'

-- %%
%fs ls 'abfss://circuitbox@deacourseexternaldl100.dfs.core.windows.net/'

-- %%
CREATE CATALOG IF NOT EXISTS circuitbox
  MANAGED LOCATION 'abfss://circuitbox@deacourseexternaldl100.dfs.core.windows.net/'
  COMMENT 'Catalog for the circuitbox data lakehouse'

-- %%
SHOW CATALOGS;

-- %%
USE  CATALOG circuitbox;

CREATE SCHEMA IF NOT EXISTS landing
  MANAGED LOCATION 'abfss://circuitbox@deacourseexternaldl100.dfs.core.windows.net/landing';

CREATE SCHEMA IF NOT EXISTS lakehouse
  MANAGED LOCATION 'abfss://circuitbox@deacourseexternaldl100.dfs.core.windows.net/lakehouse';

-- %%
SHOW SCHEMAS;

-- %%
USE CATALOG circuitbox;
USE SCHEMA landing;

CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data
  LOCATION 'abfss://circuitbox@deacourseexternaldl100.dfs.core.windows.net/landing/operational_data';

-- %%
%fs ls /Volumes/circuitbox/landing/operational_data
